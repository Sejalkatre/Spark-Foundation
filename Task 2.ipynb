# %% [markdown]
# # THE SPARK FOUNDATION
# ## GRADUATE ROTATIONAL INTERNSHIP PROGRAM
#
#
# # Task - 2
#
# # Exploratory Data Analysis - Terrorism
#
# ### By - Sejal Katre

# %%
# Important libraries we have to import

import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# Reading CSV file

df = pd.read_csv('globalterrorismdb_0718dist.csv' , low_memory = False)

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.tail(10)
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181681  201712310016   2017      12    31        NaN         0        NaN
# 181682  201712310017   2017      12    31        NaN         0        NaN
# 181683  201712310018   2017      12    31        NaN         0        NaN
# 181684  201712310019   2017      12    31        NaN         0        NaN
# 181685  201712310020   2017      12    31        NaN         0        NaN
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ...  \
# 181681      160  Philippines       5  ...
# 181682       98        Italy       8  ...
# ...

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
df.isnull().head()
# Out:
#    eventid  iyear  imonth   iday  approxdate  extended  resolution  country  \
# 0    False  False   False  False        True     False        True    False
# 1    False  False   False  False        True     False        True    False
# 2    False  False   False  False        True     False        True    False
# 3    False  False   False  False        True     False        True    False
# 4    False  False   False  False        True     False        True    False
#
#    country_txt  region  ...  addnotes  scite1  scite2  scite3  dbsource  \
# 0        False   False  ...      True    True    True    True     False
# 1        False   False  ...      True    True    True    True     False
# 2        False   False  ...      True    True    True    True     False
# 3        False   False  ...      True    True    True    True     False
# 4        False   False  ...      True    True    True    True     False
#
#    INT_LOG  INT_IDEO  INT_MISC  INT_ANY  related
# ...

# %%
df.isnull().tail()
# Out:
#         eventid  iyear  imonth   iday  approxdate  extended  resolution  \
# 181686    False  False   False  False        True     False        True
# 181687    False  False   False  False        True     False        True
# 181688    False  False   False  False        True     False        True
# 181689    False  False   False  False        True     False        True
# 181690    False  False   False  False        True     False        True
#
#         country  country_txt  region  ...  addnotes  scite1  scite2  scite3  \
# 181686    False        False   False  ...      True   False   False   False
# 181687    False        False   False  ...      True   False   False   False
# 181688    False        False   False  ...      True   False    True    True
# 181689    False        False   False  ...      True   False    True    True
# 181690    False        False   False  ...      True   False   False    True
#
#         dbsource  INT_LOG  INT_IDEO  INT_MISC  INT_ANY  related
# ...

# %%
# For viewing dataset

df
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %%
#df[df['approxdate'].isnull()]

# %%
# Here we filling NaN values with 0

new_df = df.fillna(0)
new_df
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2          0         0          0
# 1       197000000002   1970       0     0          0         0          0
# 2       197001000001   1970       1     0          0         0          0
# 3       197001000002   1970       1     0          0         0          0
# 4       197001000003   1970       1     0          0         0          0
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31          0         0          0
# 181687  201712310029   2017      12    31          0         0          0
# 181688  201712310030   2017      12    31          0         0          0
# 181689  201712310031   2017      12    31          0         0          0
# 181690  201712310032   2017      12    31          0         0          0
#
#         country         country_txt  region  ... addnotes  \
# ...

# %%
df.iyear.unique()
# Out:
# array([1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980,
#        1981, 1986, 1982, 1983, 1984, 1985, 1987, 1988, 1989, 1990, 1991,
#        1992, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016, 2017], dtype=int64)

# %%
df.country_txt.unique()
# Out:
# array(['Dominican Republic', 'Mexico', 'Philippines', 'Greece', 'Japan',
#        'United States', 'Uruguay', 'Italy', 'East Germany (GDR)',
#        'Ethiopia', 'Guatemala', 'Venezuela', 'West Germany (FRG)',
#        'Switzerland', 'Jordan', 'Spain', 'Brazil', 'Egypt', 'Argentina',
#        'Lebanon', 'Ireland', 'Turkey', 'Paraguay', 'Iran',
#        'United Kingdom', 'Colombia', 'Bolivia', 'Nicaragua',
#        'Netherlands', 'Belgium', 'Canada', 'Australia', 'Pakistan',
#        'Zambia', 'Sweden', 'Costa Rica', 'South Yemen', 'Cambodia',
#        'Israel', 'Poland', 'Taiwan', 'Panama', 'Kuwait',
#        'West Bank and Gaza Strip', 'Austria', 'Czechoslovakia', 'India',
#        'France', 'South Vietnam', 'Brunei', 'Zaire',
#        "People's Republic of the Congo", 'Portugal', 'Algeria',
#        'El Salvador', 'Thailand', 'Haiti', 'Sudan', 'Morocco', 'Cyprus',
#        'Myanmar', 'Afghanistan', 'Peru', 'Chile', 'Honduras',
# ...

# %%
df.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
# ...

# %%
# We are changing names of columns because the dataset given to us haslots of unusable columns and 
# name also not written in proper condition.

df.rename(columns={'iyear':'Year','imonth':'Month','iday':"day",'gname':'Group','country_txt':'Country','region_txt':'Region','provstate':'State','city':'City','latitude':'latitude',
    'longitude':'longitude','summary':'summary','attacktype1_txt':'Attacktype','targtype1_txt':'Targettype','weaptype1_txt':'Weapon','nkill':'kill',
     'nwound':'Wound'},inplace=True)

# %%
# we are making new dataset form folling given valriable which is usefull tp us

df = df[['Year','Month','day','Country','State','Region','City','latitude','longitude',"Attacktype",'kill',
               'Wound','target1','summary','Group','Targettype','Weapon','motive','ransompaid','ransomamt']]

# %%
# We are viewing new dataset after change 
df
# Out:
#         Year  Month  day             Country            State  \
# 0       1970      7    2  Dominican Republic              NaN
# 1       1970      0    0              Mexico          Federal
# 2       1970      1    0         Philippines           Tarlac
# 3       1970      1    0              Greece           Attica
# 4       1970      1    0               Japan          Fukouka
# ...      ...    ...  ...                 ...              ...
# 181686  2017     12   31             Somalia  Middle Shebelle
# 181687  2017     12   31               Syria         Lattakia
# 181688  2017     12   31         Philippines      Maguindanao
# 181689  2017     12   31               India          Manipur
# 181690  2017     12   31         Philippines      Maguindanao
#
#                              Region           City   latitude   longitude  \
# 0       Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# ...

# %%
plt.figure(figsize = (15,5))
sns.countplot(x = 'Region',data = df,palette = 'rocket_r',order = df["Region"].value_counts().index)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## Observations :
#
# - Middle East & North Africa, South Asia region has highest no of terror attack
# - Australasia & Oceania region has lowest no if terror attack

# %%
plt.figure(figsize = (10,12))
sns.countplot(x = "Attacktype",data = df,order = df['Attacktype'].value_counts().index)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## Observations :
#
# - Most of the terror attacks are done by Bombarding and Explosion
# - Very less terror attacks are done by Hijacking. Because airports have high security

# %%
plt.figure(figsize = (10,12))
sns.countplot(x = 'Year',data = df,palette = 'rocket_r',order = df['Year'].value_counts().index)
plt.title('Attacks per Year',fontsize = 20)
plt.ylabel('No of Attacks')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## Observation :
#
# - Most of the terror attacks occurs in year 2014.

# %%
plt.figure(figsize = (5,5))
country_kill = df.groupby('Year')['kill'].sum()
top_10_country = country_kill.sort_values(ascending = False).iloc[0:10]
top_10_country.plot(kind = 'barh')
plt.title('People Died Due to Attack')
plt.show()

# %% [markdown]
# ## Observation :
#
# - Most of the people died in the year 2014.

# %%
total_ransom = df.groupby('Country')['ransomamt'].sum()
top_10_country = total_ransom.sort_values(ascending = False).iloc[0:10]
top_10_country.plot(kind = 'barh')
plt.title('Top 10 Ransome Given Country')
plt.show()

# %% [markdown]
# ## Observation :
#
# - Italy has given the most ransome as compared to other countries.

# %%
plt.subplots(figsize=(20,10))
sns.barplot(x = df['Country'].value_counts()[:10].index, y = df['Country'].value_counts()[:10].values,palette='twilight_r')
plt.title('Top Countries Affected')
plt.xlabel('Countries')
plt.ylabel('Count')
plt.xticks(rotation = 50)
plt.show()

# %% [markdown]
# ## Observation :
#
# - Most of the terror attacks took in Iraq, Pakistan , Afghanistan and India

# %%
plt.subplots(figsize = (20,10))
sns.barplot(x = df['City'].value_counts()[:10].index, y = df['City'].value_counts()[:10].values,palette = 'cividis')
plt.title('Top Cities Affected')
plt.xlabel('Cities')
plt.ylabel('Count')
plt.xticks(rotation = 50)
plt.show()

# %% [markdown]
# ## Observation :
#
# - Most of the attack occurs in unknown cities

# %%
plt.figure(figsize = (20,10))
sns.barplot(x = df['Group'].value_counts()[:12].index, y = df['Group'].value_counts()[:12].values,palette = 'cubehelix')
plt.title('Groups behind all attacks')
plt.xlabel('Groups')
plt.ylabel('Count')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## Observations :
#
# - Most of the terror attacks are done by unknown terrorist groups.
# - Taliban , (ISIL) , (Sl) groups are activated in large numbers.

# %%
plt.figure(figsize=(20,10))
sns.barplot(x = df['Targettype'].value_counts()[:10].index,y = df['Targettype'].value_counts()[:10].values,palette = 'rocket_r')
plt.title('Targeted People',fontsize = 20)
plt.xlabel('Targets',fontsize = 15)
plt.ylabel('count',fontsize=15)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## Observations :
#
# - Terrorist has targeted the most Private Citizens and Properties
# - The second target was Military peoples.

# %%
df[['Group','kill']].groupby(['Group']).sum().drop('Unknown').sort_values('kill',ascending=False).head(10).plot(kind='barh',color='gold',figsize=(20,10),fontsize = 15)
plt.title("Top 10 terrorist group attack",fontsize=20)
plt.xlabel(" No of Killed People",fontsize=15)
plt.ylabel(" Terrorist group name",fontsize=15)
plt.show()

# %% [markdown]
# # Conclusion :
#
# - Country with the most attacks: Iraq
# - City with the most attacks: Baghdad
# - Hot Zones for Terrorist : Middle East & North Africa
# - Year with the most attacks: 2014
# - Group with the most attacks: Unknown & Taliban
# - Most Attack Types: Bombing/Explosion

# %% [markdown]
# ### Thankyou !!
